# %% [markdown]
# # Notebook de acompañamiento a
# ## *Autoría y estilo: Análisis estilométrico mediante clasificación de la* Conquista de Jerusalén
#
# Artículo realizado por:
#
# * Juan Cerezo Soler
# * José Calvo Tello
#
# Presentado y aceptado en la revista *Anales Cervantinos*

# %% [markdown]
# # Importación de herramientas

# %%
import rpy2.robjects as ro
R = ro.r

# %%
R.library("stylo")
# Out:
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
# ### stylo version: 0.6.5 ###
#
# If you plan to cite this software (please do!), use the following reference:
#     Eder, M., Rybicki, J. and Kestemont, M. (2016). Stylometry with R:
#     a package for computational text analysis. R Journal 8(1): 107-121.
#     <https://journal.r-project.org/archive/2016/RJ-2016-007/index.html>
#
# To get full BibTeX entry, type: citation("stylo")
#
#   warnings.warn(x, RRuntimeWarning)
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7f780698f148 / R:0x82d4820>
# ['stylo', 'tools', 'stats', ..., 'data..., 'meth..., 'base']

# %%
R('''
    cosinedelta <- function(x){
        # z-scoring the input matrix of frequencies
        x = scale(x)
        # computing cosine dissimilarity
        y = as.dist( x %*% t(x) / (sqrt(rowSums(x^2) %*% t(rowSums(x^2)))) )
        # then, turning it into cosine similarity
        z = 1 - y
        # getting the results
        return(z)
    }
    ''')
distances = ["dist.eder", "dist.delta","cosinedelta"]

# %% [markdown]
# # Exploración del corpus mediante clustering
#
# Realizamos dendrograma sin el texto discutido. En el artículo mostramos el dendrograma de Eder's Delta, 3000 MFW.

# %%
R.setwd("/home/jose/Desktop/analisis/corpus0/")
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7f780699a188 / R:0x872b3a8>
# ['/home/jose/Desktop/analisis']

# %%
for distance in distances:
    results = R.stylo(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 1000,
            "mfw.max" : 5000,
            "mfw.incr" : 1000,
            "mfw.list.cutoff" : 5000,
            "analysis.type" : "CA",
            "distance.measure" :  distance,
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "write.png.file" : True,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
# Out:
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating Eder's Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000

# %% [markdown]
# # Clustering
#
# ## Clustering de texto discutido con textos similares de Cervantes
#
# Realizamos dendrograma con el texto discutido. En el artículo mostramos el dendrograma de Eder's Delta, 3000 MFW.

# %%
R.setwd("/home/jose/Desktop/analisis/corpus1/")
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7f780699ccc8 / R:0x83a3628>
# ['/home/jose/Desktop/analisis/corpus0']

# %%
for distance in distances:
    results = R.stylo(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 1000,
            "mfw.max" : 5000,
            "mfw.incr" : 1000,
            "mfw.list.cutoff" : 5000,
            "analysis.type" : "CA",
            "distance.measure" :  distance,
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "write.png.file" : True,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating Eder's Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000

# %% [markdown]
# Realización de Consensus Tree con mismo corpus

# %%
for distance in distances:
    results = R.stylo(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 500,
            "mfw.max" : 5000,
            "mfw.incr" : 500,
            "mfw.list.cutoff" : 5000,
            "analysis.type" : "BCT",
            "distance.measure" :  distance,
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "write.png.file" : True,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating Eder's Delta distances...
#
# MFW used:
# 500
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
#
#
# 4500
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
# 500
#
#
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
#
#
# 4500
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# MFW used:
# 500
#
#
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
#
#
# 4500
#
#
# 5000

# %% [markdown]
# ## Clustering de texto discutido con textos menos similares de Cervantes

# %%
R.setwd("/home/jose/Desktop/analisis/corpus2/")
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7f78069a89c8 / R:0xb6bfd58>
# ['/home/jose/Desktop/analisis/corpus1']

# %%
for distance in distances:
    results = R.stylo(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 1000,
            "mfw.max" : 5000,
            "mfw.incr" : 1000,
            "mfw.list.cutoff" : 5000,
            "analysis.type" : "CA",
            "distance.measure" :  distance,
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "write.png.file" : True,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# Calculating Eder's Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000

# %%
R.setwd("/home/jose/Desktop/analisis/corpus3/")
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7f78069a7d08 / R:0x9ff68a8>
# ['/home/jose/Desktop/analisis/corpus2']

# %%
for distance in distances:
    results = R.stylo(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 1000,
            "mfw.max" : 5000,
            "mfw.incr" : 1000,
            "mfw.list.cutoff" : 5000,
            "analysis.type" : "CA",
            "distance.measure" :  distance,
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "write.png.file" : True,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating Eder's Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000
#
#
#
#
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
#
#
#
# culling @
#
# 0
#
#
#
# available features (words)
#
# 5000
#
#
#
# Calculating z-scores...
#
#
# MFW used:
# 1000
#
#
# 2000
#
#
# 3000
#
#
# 4000
#
#
# 5000

# %% [markdown]
# # Clasificación

# %%
R.setwd("/home/jose/Desktop/analisis/corpus4/")
results = R.classify(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 500,
            "mfw.max" : 5000,
            "mfw.incr" : 500,
            "mfw.list.cutoff" : 5000,
            "distance.measure" :  "dist.eder",
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )

scores_corpus4 = results[6]
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Training set successfully loaded.
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Test set successfully loaded.
#
#
#
# culling @
#
# 0
#
#
#
# available words
#
# 5000
#
#
#
# 500
#
#
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
#
#
# 4500
#
#
# 5000
#
#
#
#
#
# General attributive success:
#
# 20
#
#  of
#
# 20
#
#  (
#
# 100
#
# %, sd =
#
# 0
#
# %)
#
#
# MFWs from
#
# 500
#
#  to
#
# 5000
#
#  @ increment
#
# 500
#
#
# Culling from
#
# 0
#
#  to
#
# 0
#
#  @ increment
#
# 20
#
#
# Pronouns deleted:
#
# FALSE
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)

# %%
R.setwd("/home/jose/Desktop/analisis/corpus5/")
results = R.classify(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 500,
            "mfw.max" : 5000,
            "mfw.incr" : 500,
            "mfw.list.cutoff" : 5000,
            "distance.measure" :  "dist.eder",
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
scores_corpus5 = results[6]
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Training set successfully loaded.
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Test set successfully loaded.
#
#
#
# culling @
#
# 0
#
#
#
# available words
#
# 5000
#
#
#
# 500
#
#
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# 4500
#
#
# 5000
#
#
#
#
#
# General attributive success:
#
# 36
#
#  of
#
# 40
#
#  (
#
# 90
#
# %, sd =
#
# 17.5
#
# %)
#
#
# MFWs from
#
# 500
#
#  to
#
# 5000
#
#  @ increment
#
# 500
#
#
# Culling from
#
# 0
#
#  to
#
# 0
#
#  @ increment
#
# 20
#
#
# Pronouns deleted:
#
# FALSE

# %%
R.setwd("/home/jose/Desktop/analisis/corpus6/")
results = R.classify(
        **{
            "gui" : False,
            "analyzed.features" : "w",
            "ngram.size" : 1,
            "preserve.case" : False,
            "mfw.min" : 500,
            "mfw.max" : 5000,
            "mfw.incr" : 500,
            "mfw.list.cutoff" : 5000,
            "distance.measure" :  "dist.eder",
            "sampling" : "no.sampling",
            "display.on.screen" : False,
            "save.distance.tables" : True,
            "save.analyzed.features" : True,
            "save.analyzed.freqs" : True,
            "use.existing.freq.tables": True,
            "use.custom.list.of.files": True,
            "use.existing.wordlist": True,
        }
    )
scores_corpus6 = results[6]
# Out:
# using current directory...
#
#
#
#
# reading a custom set of features from a file...
#
#
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Training set successfully loaded.
#
#
#
#
# reading a file containing frequencies...
#
#
#
# Test set successfully loaded.
#
#
#
# culling @
#
# 0
#
#
#
# available words
#
# 5000
#
#
#
# 500
#
#
# 1000
#
#
# 1500
#
#
# 2000
#
#
# 2500
#
#
# 3000
#
#
# 3500
#
#
# 4000
# /usr/local/lib/python3.4/dist-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Read 5005 items
#
#   warnings.warn(x, RRuntimeWarning)
# 4500
#
#
# 5000
#
#
#
#
#
# General attributive success:
#
# 47
#
#  of
#
# 50
#
#  (
#
# 94
#
# %, sd =
#
# 9.7
#
# %)
#
#
# MFWs from
#
# 500
#
#  to
#
# 5000
#
#  @ increment
#
# 500
#
#
# Culling from
#
# 0
#
#  to
#
# 0
#
#  @ increment
#
# 20
#
#
# Pronouns deleted:
#
# FALSE

# %%
list(scores_corpus4)
# Out:
# [100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0]

# %%
import pandas as pd
columns = ["500", "1000", "1500", "2000", "2500","3000","3500","4000","4500","5000"]
dataframe = pd.DataFrame([list(scores_corpus4), list(scores_corpus5), list(scores_corpus6)], columns = columns, index = ["corpus4", "corpus 5", "corpus 6"])

# %%
dataframe
# Out:
#             500   1000   1500   2000   2500   3000   3500   4000   4500   5000
# corpus4   100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0
# corpus 5   50.0   75.0   75.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0
# corpus 6   80.0   80.0   80.0  100.0  100.0  100.0  100.0  100.0  100.0  100.0

# %%
import matplotlib.pyplot as plt
import numpy as np


results_list = [item[0] + "-" + item[1] for item in list(zip(columns,["Cervantes"]*10))]

# %matplotlib inline
dataframe.boxplot(medianprops = dict(linewidth=5), figsize=(5,5))
plt.ylim((0,110))
plt.xticks(np.arange(1, len(columns)+1, 1), results_list, rotation=90)
plt.ylabel("Resultado de evaluación")
plt.xlabel("MFW y autor clasificado")
plt.title("Resultados de clasificación\nde La conquista de Jerusalén en tres subcorpus")
plt.tight_layout()
plt.savefig("/home/jose/Desktop/analisis/results.png", dpi=300)
plt.show()
